# %%
using DataFrames
using CSV
using HTTP

# %%
url="http://prac.im.pwr.edu.pl/~wyloman/szcz_2022_2023/zad1_lista1.txt"
# Out:
# "http://prac.im.pwr.edu.pl/~wyloman/szcz_2022_2023/zad1_lista1.txt"

# %%
?CSV.File
# Out:
#   CSV.File(input; kwargs...) => CSV.File
#
#   Read a UTF-8 CSV input and return a CSV.File object, which is like a
#   lightweight table/dataframe, allowing dot-access to columns and iterating
#   rows. Satisfies the Tables.jl interface, so can be passed to any valid sink,
#   yet to avoid unnecessary copies of data, use CSV.read(input, sink;
#   kwargs...) instead if the CSV.File intermediate object isn't needed.
#
#   The input argument can be one of:
#
#     •  filename given as a string or FilePaths.jl type
#
#     •  a Vector{UInt8} or SubArray{UInt8, 1, Vector{UInt8}} byte buffer
#
#     •  a CodeUnits object, which wraps a String, like codeunits(str)
#
#     •  a csv-formatted string can also be passed like IOBuffer(str)
#
#     •  a Cmd or other IO
#
#     •  a gzipped file (or gzipped data in any of the above), which will
#        automatically be decompressed for parsing
#
#     •  a Vector of any of the above, which will parse and vertically
# ...

# %%
df = DataFrame(CSV.File("dane.txt"))
# Out:
# ┌ Warning: thread = 1 warning: parsed expected 1 columns, but didn't reach end of line around data row: 1. Parsing extra columns and widening final columnset
# └ @ CSV C:\Users\Kacper\.julia\packages\CSV\jFiCn\src\file.jl:579
# ┌ Warning: thread = 1 warning: parsed expected 6 columns, but didn't reach end of line around data row: 3. Parsing extra columns and widening final columnset
# └ @ CSV C:\Users\Kacper\.julia\packages\CSV\jFiCn\src\file.jl:579
# ┌ Warning: thread = 1 warning: only found 6 / 7 columns around data row: 5. Filling remaining columns with `missing`
# └ @ CSV C:\Users\Kacper\.julia\packages\CSV\jFiCn\src\file.jl:578
# ┌ Warning: thread = 1 warning: only found 6 / 7 columns around data row: 9. Filling remaining columns with `missing`
# └ @ CSV C:\Users\Kacper\.julia\packages\CSV\jFiCn\src\file.jl:578
# ┌ Warning: thread = 1 warning: only found 6 / 7 columns around data row: 11. Filling remaining columns with `missing`
# ...

# %%
names(df)
# Out:
# 1-element Vector{String}:
#  "   xy"

# %%
transform!(df, :(    xy) => ByRow(x -> split(x, ' ')) => [:x, :y])
# Out:
# ArgumentError: column name :xy not found in the data frame
#
# Stacktrace:
#   [1] lookupname
#     @ C:\Users\Kacper\.julia\packages\DataFrames\3mEXm\src\other\index.jl:288 [inlined]
#   [2] getindex
#     @ C:\Users\Kacper\.julia\packages\DataFrames\3mEXm\src\other\index.jl:297 [inlined]
#   [3] normalize_selection(idx::DataFrames.Index, sel::Pair{Symbol, Pair{ByRow{var"#7#8"}, Vector{Symbol}}}, renamecols::Bool)
#     @ DataFrames C:\Users\Kacper\.julia\packages\DataFrames\3mEXm\src\abstractdataframe\selection.jl:241
#   [4] (::DataFrames.var"#405#406"{Bool, DataFrame})(c::Pair{Symbol, Pair{ByRow{var"#7#8"}, Vector{Symbol}}})
#     @ DataFrames .\none:0
#   [5] iterate
#     @ .\generator.jl:47 [inlined]
#   [6] collect_to!(dest::Vector{Base.OneTo{Int64}}, itr::Base.Generator{Vector{Any}, DataFrames.var"#405#406"{Bool, DataFrame}}, offs::Int64, st::Int64)
#     @ Base .\array.jl:782
# ...

# %%
@rtransform df $[:x, :y] = split(:xy)
# Out:
# LoadError: UndefVarError: @rtransform not defined
# in expression starting at In[18]:1
#
# Stacktrace:
#  [1] top-level scope
#    @ :0
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196

# %%
DataFrame(CSV.File(HTTP.get(url).body))
# Out:
# 999×1 DataFrame
#  Row │    2.0490626e-01  -3.2205502e+00
#      │ String
# ─────┼──────────────────────────────────
#    1 │    9.8945649e-02  -1.1258680e+00
#    2 │    2.0636720e+00   1.2928829e+01
#    3 │    9.0607812e-02   6.9178623e+00
#    4 │    4.5829762e-01  -6.0477376e-01
#    5 │    2.3274886e+00   1.0360501e+01
#    6 │    1.2783436e+00   3.4827574e+00
#    7 │    6.0352310e-01   8.1949464e+00
#    8 │    4.3422419e-02  -7.8077760e-01
#    9 │    3.5742692e-02   1.0832976e+01
#   10 │    1.8476121e+00  -1.9517961e-01
#   11 │    2.9848279e-02   4.4988383e+00
#   ⋮  │                ⋮
#  990 │    1.1475047e+00   1.5785078e+01
#  991 │    2.0513202e-01   1.0432906e+01
#  992 │    2.3689579e-01   8.1933621e+00
#  993 │    1.5985907e-01  -3.7372587e-02
#  994 │    6.8193701e-01   9.5902234e+00
#  995 │    4.5308926e-01   2.7684125e+00
#  996 │    5.0352247e-02   1.6329001e+00
#  997 │    8.1201145e-01   7.2318393e+00
#  998 │    2.8130971e+00   6.2687607e+00
# ...

# %%
tmp=date.

# %%
date=DataFrame(CSV.File("dane.txt"))
# Out:
# 999×1 DataFrame
#  Row │    2.0490626e-01  -3.2205502e+00
#      │ String
# ─────┼──────────────────────────────────
#    1 │    9.8945649e-02  -1.1258680e+00
#    2 │    2.0636720e+00   1.2928829e+01
#    3 │    9.0607812e-02   6.9178623e+00
#    4 │    4.5829762e-01  -6.0477376e-01
#    5 │    2.3274886e+00   1.0360501e+01
#    6 │    1.2783436e+00   3.4827574e+00
#    7 │    6.0352310e-01   8.1949464e+00
#    8 │    4.3422419e-02  -7.8077760e-01
#    9 │    3.5742692e-02   1.0832976e+01
#   10 │    1.8476121e+00  -1.9517961e-01
#   11 │    2.9848279e-02   4.4988383e+00
#   ⋮  │                ⋮
#  990 │    1.1475047e+00   1.5785078e+01
#  991 │    2.0513202e-01   1.0432906e+01
#  992 │    2.3689579e-01   8.1933621e+00
#  993 │    1.5985907e-01  -3.7372587e-02
#  994 │    6.8193701e-01   9.5902234e+00
#  995 │    4.5308926e-01   2.7684125e+00
#  996 │    5.0352247e-02   1.6329001e+00
#  997 │    8.1201145e-01   7.2318393e+00
#  998 │    2.8130971e+00   6.2687607e+00
# ...
